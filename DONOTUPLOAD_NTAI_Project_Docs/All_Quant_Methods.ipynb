# %%
import yfinance as yf
import quantstats as qs

# Define the list of methods
graph_methods = ['compsum', 'drawdown_details', 'implied_volatility', 'kelly_criterion', 'max_drawdown', 'monthly_returns', 'outlier_loss_ratio', 'outlier_win_ratio', 'outliers', 'payoff_ratio', 'profit_factor', 'profit_ratio', 'r2', 'r_squared', 'rar', 'recovery_factor', 'remove_outliers', 'risk_of_ruin', 'risk_return_ratio', 'rolling_greeks', 'ror', 'sharpe', 'skew', 'sortino', 'adjusted_sortino', 'tail_ratio', 'to_drawdown_series', 'ulcer_index', 'ulcer_performance_index', 'upi', 'utils', 'value_at_risk', 'var', 'volatility', 'win_loss_ratio', 'win_rate', 'worst']
table_methods = ['avg_loss', 'avg_return', 'avg_win','best', 'cagr', 'calmar', 'common_sense_ratio', 'comp','conditional_value_at_risk', 'consecutive_losses', 'consecutive_wins', 'cpc_index', 'cvar', 'expected_return', 'expected_shortfall', 'exposure', 'gain_to_pain_ratio', 'geometric_mean', 'ghpr', ]
#methods which contain a benchmark error ['compare', 'greeks','information_ratio',]
# Input the stock
methods = graph_methods + table_methods
stock = input("Enter the stock symbol: ")

# Download the stock data
data = yf.download(stock, start="2020-01-01", end="2022-12-31")

# Calculate the returns
returns = data['Close'].pct_change().dropna()

# Apply each method and print the result
for method in methods:
    try:
        result = getattr(qs.stats, method)(returns)
        print(f"{method}: {result}")
    except Exception as e:
        print(f"Error calculating {method}: {e}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# compsum: Date
# 2021-02-08    0.004634
# 2021-02-09    0.005620
# 2021-02-10    0.009563
# 2021-02-11    0.006606
# 2021-02-12    0.001676
#                 ...
# 2022-12-23   -0.785073
# 2022-12-27   -0.787045
# 2022-12-28   -0.772257
# 2022-12-29   -0.776200
# 2022-12-30   -0.774229
# Name: Close, Length: 479, dtype: float64
# drawdown_details:          start      valley         end  days  max drawdown  99% max drawdown
# 0   2021-02-08  2021-02-17  2021-02-18    11     -0.778209         -0.489718
# 1   2021-02-22  2021-03-02  2021-03-18    25     -1.292248         -0.804019
# 2   2021-03-22  2021-03-31  2021-04-05    15     -0.810536         -0.406091
# 3   2021-04-07  2021-04-07  2021-04-08     2      0.202025          0.705642
# 4   2021-04-12  2021-04-12  2021-04-12     1      0.100102               NaN
# ..         ...         ...         ...   ...           ...               ...
# ...
